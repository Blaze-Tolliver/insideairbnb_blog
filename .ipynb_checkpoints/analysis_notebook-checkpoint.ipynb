# %% [markdown]
# # Looking at Air BnB listings in Bristol, UK
# Importing the needed packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
# %matplotlib inline
from textblob import TextBlob
import statsmodels.api as sm

# %% [markdown]
# #### Question One: Are there long-term and periodic trends for Airbnb usage in Bristol since the first listings in 2011?

# %%
#importing reviews dataset, which shows date of each review for each listing
reviews = pd.read_csv('./reviews.csv', parse_dates=["date"]) 
reviews.head()
# Out:
#    listing_id       date
# 0       70820 2013-10-18
# 1       70820 2013-10-28
# 2       70820 2013-11-12
# 3       70820 2014-05-17
# 4       70820 2014-06-15

# %% [markdown]
# Reviews contains two columns only - the listing_id and the date of the review. There are no missing values. For the sake of this analysis, I assume the review took place in the same month as the actual stay. There is no other record of stay dates.
#
# Next I resampled reviews to calculate cummulative monthly review counts for the entire Bristol area. I considered trimming the timeseries to not include 2020 so that long-term trends pre-covid could be analyzed, but I decided to include 2020 to show how the long-term trend suddenly changes. This illustrates the uncertainty that must be accounted for in trying to extrapolate trend data into the future.

# %%
def resample_reviews(reviews):
    
    """Function to resample reviews dataset to monthly total reviews. The result is stored in the monthly_reviews dataframe.

    Args:
        reviews (dataframe): the dataframe containing each review for each airbnb listing. One review per row.
        
    Returns:
        monthly_reviews (dataframe): reviews dataframe resampled so that each row represents a month, and shows
                                     reviews_per_month

    """
    #setting date as the index
    reviews.index = reviews['date']
    #resampling to monthly count of reviews for all listings combined, and limiting
    monthly_reviews = reviews.resample('M', label = 'left', loffset = '1d').count()
    monthly_reviews['reviews_per_month'] = monthly_reviews.date
    monthly_reviews = monthly_reviews.drop(['listing_id', 'date'], axis = 1)
    
    return monthly_reviews

monthly_reviews = resample_reviews(reviews)
monthly_reviews.head()
# Out:
#             reviews_per_month
# date
# 2011-07-01                  2
# 2011-08-01                  3
# 2011-09-01                  2
# 2011-10-01                  2
# 2011-11-01                  3

# %% [markdown]
# Plot of monthly reviews, showing strong growth in reviews since first listing reviews in 2011. Apparent seasonality as well.

# %%
monthly_reviews.plot()

# %% [markdown]
# Although the dramatic upward trend in reviews is clearly evident, it would be nice to apply a model that will attempt to separate out the underlying long-term trend, the seasonlity, and residual variations. I chose to use the statsmodels time series analysis seasonal decomposition filter.
#
# I used the 'additive' model option, because the results are easier for the observer to interpret. If I were going to pursue this analysis further, I would have to compare the performance and applicability of the 'additive' vs. the 'multiplicative' models. This is really just a first attempt at getting familiar with seasonality filtering.

# %%
def analyze_seasonality(monthly_reviews):


    """Function to apply an additive seasonal decomposition filter to a timeseries of counts.
        The result is a plot of the filter components, and an object containing the model.

    Args:
        monthly_reviews (dataframe): reviews dataframe resampled so that each row represents a month, and shows
        reviews_per_month.
        
    Returns:
        decomposition (other): object containing the seasonal decomposition model 

    """
    #trend and seasonality analysis
    decomposition = sm.tsa.seasonal_decompose(monthly_reviews, model = 'additive')
    
    #plots of trend, seasonality, and residuals for the additive seasonal decomposition model
    fig = decomposition.plot()
    plt.rcParams['figure.figsize'] = [12.0, 12.0]
    
    return decomposition

decomposition = analyze_seasonality(monthly_reviews)

# %% [markdown]
# The filter identified some seasonality, but in reality the model only fits decently in 2016. In the years before 2016, the residuals are canceling out the seasonality. In the years after 2016, the residuals are boosting the seasonality.

# %%
def plot_trend(monthly_reviews, decomposition):

    """Function to plot actual monthly review count vs the seasonal decomposition model trend line.

    Args:
        monthly_reviews (dataframe): reviews dataframe resampled so that each row represents a month, and shows
                                     reviews_per_month.
        decomposition (other): object containing the seasonal decomposition model                              
        
    Returns:
        None

    """
    
    fig, ax = plt.subplots()
    ax.grid(True)
    plt.plot(monthly_reviews.index, monthly_reviews['reviews_per_month'], c='blue', label = 'Data')
    plt.plot(decomposition.trend.index, decomposition.trend, c='red', label = 'Trend')
    plt.xlabel('Year')
    plt.ylabel('Reviews per Month')
    plt.title('Growth in Bristol Airbnb Usage')
    plt.legend()
    
plot_trend(monthly_reviews, decomposition)

# %% [markdown]
# #### Question One Conclusion
# Since 2011, there has been a consistent uptrend in listing reviews. However, Coronavirus lock-down means that the uptrend is now broken. It will be interesting to see how long it takes for the uptrend to continue after restrictions are eased.
#
# There is a seasonal component to the variation in listing reviews. Due to the rapid growth in listing reviews, it is difficult to isolate the seasonal contribution to variation without applying more advanced modeling techniques.

# %% [markdown]
# #### Questions Two & Three: What does it take to have a frequently visited listing that remains popular long-term? Can the written comment sentiment be used to approximate the average numeric rating for listings?

# %%
#here's a more detailed reviews dataset that has written comments from the reviews
reviews_detail = pd.read_csv('./reviews_detail.csv', parse_dates=["date"]) 
reviews_detail.head()
# Out:
#    listing_id        id       date  reviewer_id reviewer_name  \
# 0       70820   8163487 2013-10-18      7538116       Neralee
# 1       70820   8397676 2013-10-28      9601180         Terry
# 2       70820   8706695 2013-11-12      9697980         Alice
# 3       70820  13024371 2014-05-17      2388955        Thomas
# 4       70820  14247963 2014-06-15     16317003     Dimitrije
#
#                                             comments
# 0  We loved our stay with Sarah in Bristol. She w...
# 1  Sarah gave us and Laddie our dog a very warm w...
# 2  Exactly as described on the site and praised b...
# 3  Sarah was great. She was warm and welcoming, e...
# 4  The experience was really great at Sarah's hou...

# %% [markdown]
# I applied the TextBlog sentiment analysis tool to see if I could distinguish well reviewed listings from poorly reviewed listings. The reviews_detail dataset doesn't contain the numeric review scores. I will have to relate the aggregated review sentiment to the aggregated review score from the list_detail dataset.

# %%
def calculate_sentiment(reviews_detail):

    """Function to calculate the mean TextBlob sentiment polarity for each listing, 
        and filter out listings with no comments.

    Args:
        reviews_detail (dataframe): reviews dataframe with each review for each listing, including the written comments.                             
        
    Returns:
        listing_mean_sent (dataframe): dataframe with mean sentiment polarity for each listing with at least one written comment.

    """
    
    #calculating sentiment polarity for each review comment, using TextBlob
    sentiment = []
    for row in reviews_detail.comments:
        text = str(row)
        comment = TextBlob(text)
        polarity = comment.sentiment.polarity
        sentiment.append(polarity)

    #append the sentiment list to reviews_detail df
    reviews_detail['sentiment'] = sentiment 

    #aggregate mean review sentiment polarity for each listing_id, and drop listings with < 1 comments
    listing_mean_sentiment = pd.concat([reviews_detail.groupby('listing_id')['sentiment'].median(), reviews_detail.groupby('listing_id')['comments'].count()], axis = 1)
    listing_mean_sentiment = listing_mean_sentiment[listing_mean_sentiment.comments >= 1]
    
    return listing_mean_sent

listing_mean_sentiment = calculate_sentiment(reviews_detail)

# %% [markdown]
# Now I have the mean sentiment polarity score for each listing that had at least 1 written review comment. Polarity can range from -1 to 1, where -1 is entirely negative, 0 is neutral, and 1 is entirely positive.

# %%
def merge_sentiment_to_listings(listing_mean_sentiment, listings_path, date_parse_list):

    """Function to merge the mean listing sentiment polarity to the listing details df and to calculate
       the listing age column as the difference between first review date and last review date.

    Args:
        listing_mean_sent (dataframe): dataframe with mean sentiment polarity for each listing with 
                                       at least one written comment.
        listings_path (str): path to the listings detail csv file from Inside Airbnb.
        date_parse_list (list): list of date columns to parse.
        
    Returns:
        merged_listings (dataframe): result of merging sentiment polarity with listings detail file.

    """

    list_detail = pd.read_csv(listings_path, parse_dates= date_parse_list)
    list_detail.index =   list_detail['id']
    merged_listings = list_detail.merge(listing_mean_sent, how = 'left', left_index = True, right_index = True)
    merged_listings['listing_age'] = merged_listings.last_review.dt.year - merged_listings.first_review.dt.year
    
    return merged_listings
    
date_parse_list = ["last_review", 'first_review']
listings_path = './listings_detail.csv'

merged_listings = merge_sentiment_to_listings(listing_mean_sentiment, listings_path, date_parse_list)
merged_listings.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  2.810000e+03  2.810000e+03            0.0         0.0             0.0
# mean   2.599634e+07  2.020032e+13            NaN         NaN             NaN
# std    1.119000e+07  8.399932e-01            NaN         NaN             NaN
# min    7.082000e+04  2.020032e+13            NaN         NaN             NaN
# 25%    1.789451e+07  2.020032e+13            NaN         NaN             NaN
# 50%    2.632456e+07  2.020032e+13            NaN         NaN             NaN
# 75%    3.595197e+07  2.020032e+13            NaN         NaN             NaN
# max    4.295874e+07  2.020032e+13            NaN         NaN             NaN
#
#             host_id  host_listings_count  host_total_listings_count  \
# count  2.810000e+03          2810.000000                2810.000000
# mean   9.285494e+07            13.024555                  13.024555
# std    8.645724e+07            35.682250                  35.682250
# min    5.253600e+04             0.000000                   0.000000
# 25%    2.338133e+07             1.000000                   1.000000
# 50%    6.519263e+07             2.000000                   2.000000
# 75%    1.339409e+08             4.000000                   4.000000
# max    3.413910e+08           703.000000                 703.000000
#
#        neighbourhood  neighbourhood_group_cleansed  ...  review_scores_value  \
# count            0.0                           0.0  ...          2403.000000
# mean             NaN                           NaN  ...             9.435289
# std              NaN                           NaN  ...             0.822935
# min              NaN                           NaN  ...             2.000000
# 25%              NaN                           NaN  ...             9.000000
# 50%              NaN                           NaN  ...            10.000000
# 75%              NaN                           NaN  ...            10.000000
# max              NaN                           NaN  ...            10.000000
#
#        jurisdiction_names  calculated_host_listings_count  \
# count                 0.0                     2810.000000
# mean                  NaN                       11.738078
# std                   NaN                       30.710219
# min                   NaN                        1.000000
# 25%                   NaN                        1.000000
# 50%                   NaN                        1.000000
# 75%                   NaN                        3.000000
# max                   NaN                      126.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  2810.000000
# mean                                      6.821708
# std                                      17.962638
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       1.000000
# max                                      69.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   2810.000000
# mean                                       1.122776
# std                                        1.929945
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# 75%                                        1.000000
# max                                       15.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# count                                  2810.000000        2447.000000
# mean                                      0.002491           1.900396
# std                                       0.049858           2.018885
# min                                       0.000000           0.020000
# 25%                                       0.000000           0.430000
# 50%                                       0.000000           1.190000
# 75%                                       0.000000           2.730000
# max                                       1.000000          17.140000
#
#          sentiment     comments  listing_age
# count  2446.000000  2446.000000  2447.000000
# mean      0.402923    43.620605     1.574990
# std       0.114348    66.675897     1.584108
# min      -0.250000     1.000000     0.000000
# 25%       0.367708     5.000000     0.000000
# 50%       0.411658    18.000000     1.000000
# 75%       0.453892    52.000000     2.000000
# max       1.000000   604.000000     8.000000
#
# [8 rows x 48 columns]

# %% [markdown]
# To compare the polarity values to each listing's attributes, I merged the listing_mean_sentiment dataframe with the listings detail csv file from Inside Airbnb. The listings detail file shows all available attributes for each listing. I also calculated the age in years of each listing in order to use age as the hue in the scatterplot below.

# %% [markdown]
# Before comparing sentiment polarity with listing numerical review scores, I took a look at the relationship between listing's review scores the number of reviews. The scatter plot below is intended to help visualize what it takes to have a popular listing.

# %%
def make_scatterplot(merged_listings):

    """Function to scatterplot each listing's number of reviews vs mean review score, with listing age as 
        the hue and size.

    Args:
        merged_listings (dataframe): result of merging sentiment polarity with listings detail file.
        
    Returns:
        None

    """
    
    plt.figure(figsize=(10, 8))
    sns.scatterplot(x = merged_listings.review_scores_rating, y = merged_listings.comments, 
                    hue = merged_listings.listing_age, size = merged_listings.listing_age, 
                    sizes = (10,400), legend = 'brief', alpha = 0.5)
    plt.xlabel('Listing Review Score')
    plt.ylabel('Number of Reviews')
    
make_scatterplot(merged_listings)

# %% [markdown]
# Looking at the relationship between mean listing review score and number of reviews, it's pretty clear that listings that get poor reviews don't get many visitors, and generally don't last for many years. It also appears to take a few years to accummulate hundreds of reviews.

# %%
merged_listings.review_scores_rating.describe()
# Out:
# count    2409.000000
# mean       94.372769
# std         7.731028
# min        20.000000
# 25%        92.000000
# 50%        97.000000
# 75%        99.000000
# max       100.000000
# Name: review_scores_rating, dtype: float64

# %% [markdown]
# #### Question 2 Conclusion
# Looking at the relationship between mean listing review score and number of reviews, it's pretty clear that listings that get poor reviews don't get many visitors. It's also clear that poorly reviewed listings generally don't last for many years.
#
# In fact, in order to even register in the 25th percentile of mean listing scores, your listing will need to garner a 92%! To be average (median), you'll need a 97%.
#
# People seem to be pretty risk averse when it comes to choosing an Airbnb. Therefore, it would behoove anyone considering listing a place to be on their A-game before opening up to visitors.
#
# On the other hand, staying at an Airbnb is a little more personal of an experience than buying something online. Therefore, it feels a bit more confrontational to leave a poor Airbnb review. I think that is partially why the reviews scores tend to be so high.

# %% [markdown]
# ##### Text sentiment analysis
# For the text sentiment analysis, I chose to consider a bad listing to have a review score rating below 70% in order to give the sentiment analysis the absolute worst listings to compare with the absolute best listings, which I defined as a review score rating >= 97%.

# %%
def compare_sentiment_to_score(merged_listings):

    """Function to boxplot the listing sentiment polarity based upon categorized values of the review score.
      Review score is categorized into bad, Ok, and great. Bad is < 70, Ok is from 70 to < 97, great is >= 97.

    Args:
        merged_listings (dataframe): result of merging sentiment polarity with listings detail file.
        
    Returns:
        sentiment_accuracy (dataframe): sentiment, review score, and score category for each listing.

    """
    
    sentiment_accuracy = merged_listings[['sentiment','review_scores_rating']].dropna(axis = 0, how = 'any')
    sentiment_accuracy['score_good'] = np.where(sentiment_accuracy['review_scores_rating'] >= 70, 'Ok', 'bad')
    sentiment_accuracy['score_good'].where(sentiment_accuracy['review_scores_rating'] < 97.0, other = 'great',
                                           inplace = True)
    sentiment_accuracy = sentiment_accuracy.drop(['review_scores_rating'], axis = 1)
    sns.boxplot(x = sentiment_accuracy.score_good, y = sentiment_accuracy.sentiment, orient = 'v')
    plt.xlabel('Listing Review Score')
    plt.ylabel('Listing Median Sentiment')
    
    #return sentiment_accuracy

compare_sentiment_to_score(merged_listings)

# %% [markdown]
# #### Question 3 Conclusion
# The interquartile range (IQR) of listing median sentiment for bad listings does not overlap with the IQR of OK and great listings. This is just a first brush at using text sentiment analysis. As it is, I could see a use for it in getting an overall picture of review scores. However, to be useful in distinguishing which score category a particular listing falls in, more work would be needed. Of course there is no guarantee that people's written comments convey the sentiment of the score they leave.

# %% [markdown]
# #### Question 4: What are the price distributions in each neighborhood for short-term listings?

# %%
def filter_listings(listing_detail_path, minimum_nights, minimum_neighborhood_listings, oldest_last_review):

    """Function to filter listings and neighborhoods. Filters listings by minimum nights, and remove listings with no
        last review. Filter neighborhoods by minimum number of listings.

    Args:
        listing_detail_path (str): The path to the listing details data from Inside Airbnb. 
        minimum_nights(int): The highest allowable minimum nights. Function filters out listings with higher minimum.
        minimum_neighborhood_listings(int): The minimum number of listings in a neighborhood.
        oldest_last_review(str): The oldest allowable last review for a listing to be included ('YYYY-MM-DD').
        
    Returns:
        neighborhood(dataframe): the filtered listing details data

    """
    list_detail = pd.read_csv(listing_detail_path, parse_dates=["last_review", 'first_review'])
    list_detail_reviewed = list_detail.dropna(axis = 0, subset = ['last_review'])
    list_detail_current = list_detail_reviewed[list_detail_reviewed['last_review'] > oldest_last_review]
    list_detail_min_nights = list_detail_current[list_detail_current['minimum_nights_avg_ntm'] <= minimum_nights]
    
    neighborhood = pd.concat([list_detail_min_nights['neighbourhood_cleansed'], 
                              list_detail_min_nights['price'].str.replace('$', '').str.replace(',', '').astype(float)], 
                             axis = 1)
    neighborhood.index = neighborhood['neighbourhood_cleansed']
    neighborhood_length = neighborhood.shape[0]
    neighborhood['min_listings'] = neighborhood['neighbourhood_cleansed'].groupby('neighbourhood_cleansed').count() >= minimum_neighborhood_listings
    neighborhood = neighborhood[neighborhood.min_listings]
    neighborhood = neighborhood.reset_index(drop = True)
    neighborhood = neighborhood.drop(['min_listings'], axis = 1)
    print('minimum nights filtered out:', 100-100*neighborhood.shape[0]/list_detail_current.shape[0],'%','\n',
          'minimum listings filtered out:', 100-100*neighborhood.shape[0]/neighborhood_length,'%',
          '\n',neighborhood.describe())
    return neighborhood

# %% [markdown]
# I filtered out listings that haven't had a review in 2019 or 2020. I set maximum minimum nights at 3 days because I'm interested short-term rental pricing only. This filters out less than 8% of the eligible listings. I set minimum listings per neighborhood at 10 in an attempt to get a representative sample from neighborhoods. This filters out less than 1% of listings.

# %%
neighborhoods = filter_listings('./listings_detail.csv', 3, 10, '2018-12-31')
# Out:
# minimum nights filtered out: 7.529976019184659 %
#  minimum listings filtered out: 0.6185567010309256 %
#               price
# count  1928.000000
# mean     79.078320
# std      89.899405
# min      10.000000
# 25%      36.000000
# 50%      60.000000
# 75%      90.000000
# max    1600.000000

# %% [markdown]
# In order to understand price differences among Bristol's neighborhoods, I boxplotted listing price by neighborhood.

# %%
def boxplot_neighborhood_prices(neighborhood, outliers_symbol):

    """Function to boxplot listing prices by neighborhood, sorted by median price.

    Args:
        neighborhood (dataframe): The dataframe showing each listing's price and neighborhood. 
        outliers_symbol(str): symbol to use for outliers, use empty string to remove outliers.
        
    Returns:
        None

    """
    neighborhood_median_price = neighborhood.groupby('neighbourhood_cleansed')['price'].median()
    neighborhood_median_price = neighborhood_median_price.sort_values(ascending = False)
    neighborhood_pivot = neighborhood.pivot(columns = 'neighbourhood_cleansed', values = 'price')
    neighborhood_pivot[neighborhood_median_price.index].plot.box(vert=False, figsize=(15, 15), sym = outliers_symbol)
    plt.xlabel('Price in GBP')
    plt.ylabel('Neighborhood')
    plt.title('Price Distribution by Neighborhood')
    
boxplot_neighborhood_prices(neighborhoods, '+')

# %% [markdown]
# However, the price outliers are dominating the figure. Some of the prices may be errors, like prices that are meant for weekly or monthly rentals. Some places may be event or wedding venues. I decided to filter out the outliers.

# %%
boxplot_neighborhood_prices(neighborhoods, '')

# %% [markdown]
# #### Question 4 Conclusion
# This information is useful for local government planning purposes, or potentially useful for an individual looking to list with Airbnb. Clearly there are differences between neighborhood pricing, but it isn't clear how to price your listing until you compare with similar listings. However, if there aren't any similar listings in your neighborhood, but are in other neighborhoods, you could use this figure to convert the listing price to your neighborhood's relative value.
